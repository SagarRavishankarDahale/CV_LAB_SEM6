# %%
#name:sagar ravishankar dahale
#prn.no:1032211914
#div:A1
#batch:A4

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import scipy

# %%
img = cv2.imread('textures.jpg')
gray=cv2.resize(img,(1000,1000))
g = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.subplot(1,2,1)
plt.imshow(img);
plt.subplot(1,2,2)
plt.imshow(gray,cmap='gray');

# %%
from skimage.feature import graycomatrix, graycoprops
from skimage import data

# %%
print(gray)
# Out:
# [[[ 19  24  25]
#   [ 20  25  26]
#   [ 11  16  17]
#   ...
#   [160 156 138]
#   [164 160 142]
#   [164 160 142]]
#
#  [[ 22  27  29]
#   [ 18  23  24]
#   [ 15  20  21]
#   ...
#   [162 158 140]
#   [165 161 143]
#   [164 160 142]]
#
#  [[ 27  32  35]
#   [ 19  24  26]
#   [ 25  30  31]
#   ...
#   [165 161 143]
#   [167 163 145]
#   [166 162 144]]
#
#  ...
#
#  [[ 34  38  49]
#   [ 19  24  33]
#   [ 23  28  36]
#   ...
#   [193 191 174]
#   [162 160 143]
#   [139 137 119]]
#
#  [[ 86  90 101]
#   [ 47  52  61]
#   [ 22  28  35]
#   ...
#   [183 181 163]
#   [159 157 138]
#   [121 119 100]]
#
#  [[138 142 153]
#   [ 79  84  93]
#   [ 26  32  39]
#   ...
#   [179 177 159]
#   [159 157 138]
#   [106 105  85]]]

# %%
PATCH_SIZE = 60
textures = [(50,110),(250, 310),(450, 510),(650, 710),(850, 910)]
grass_patches = []
for loc in textures:
    grass_patches.append(gray[loc[0]:loc[0] + PATCH_SIZE,
                               loc[1]:loc[1] + PATCH_SIZE])
print(len(grass_patches[0]))
print(grass_patches[0].shape)
# Out:
# 60
# (60, 60, 3)

# %%
plt.imshow(grass_patches[3],cmap='gray')

# %%
plt.subplot(3,2,1)
plt.imshow(grass_patches[0],cmap='gray')

plt.subplot(3,2,2)
plt.imshow(grass_patches[1],cmap='gray')

plt.subplot(3,2,3)
plt.imshow(grass_patches[2],cmap='gray')

plt.subplot(3,2,4)
plt.imshow(grass_patches[3],cmap='gray')

plt.subplot(3,2,5)
plt.imshow(grass_patches[4],cmap='gray')
